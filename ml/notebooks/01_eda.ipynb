# %% [markdown]
# # EDA — Laptop Price Prediction
# Goal: understand distributions, missingness, and feature/target relationships before training.

# %%
import pandas as pd
from shared.csv_columns import CSV_TO_FIELD
df = pd.read_csv('../../data/laptop_price_dataset.csv').rename(columns=CSV_TO_FIELD)
df.describe(include='all')
